# %%
import pandas as pd
import re
import pickle

# %%
with open(r"C:\Users\admin\Desktop\Mencius_research\Mencius_research\[논문 작업용] 맹자절문 삭제부분.txt", 'rt', encoding='cp949') as f:
    file = [t.replace('\n','') for t in f.readlines()]

# %%
file
# Out:
# ['',
#  '',
#  '',
#  '',
#  '孟子',
#  '',
#  '빨간색: 맹자절문 삭제된 부분',
#  '',
#  'I. 梁惠王上',
#  'Liang Hui Wang I',
#  '1·1',
#  '孟子見梁惠王。',
#  'Mencius went to see king Hui of Liang. ',
#  '王曰：「?不?千里而來，亦將有以利吾國乎？」',
#  "The king said, 'Venerable sir, since you have not counted it far to come here, a distance of a thousand li, may I presume that you are provided with counsels to profit my kingdom?'",
#  '孟子對曰：「王何必曰利？',
#  'Mencius replied, \'Why must your Majesty use that word "profit?" ',
#  '亦有仁義而已矣。',
#  "What I am provided with, are counsels to benevolence and righteousness, and these are my only topics. '",
#  '王曰何以利吾國？',
#  'If your Majesty say, "What is to be done to profit my kingdom?" ',
#  '大夫曰何以利吾家？',
#  'the great officers will say, "What is to be done to profit our families?" ',
#  '士庶人曰何以利吾身？',
#  'and the inferior officers and the common people will say, "What is to be done to profit our persons?" ',
#  '上下交征利，而國危矣。',
# ...

# %%
p = re.compile(r'[^a-zA-Z0-9\s·]+')
preprocessed=[re.sub(p,'',t) for t in file if t!='']
preprocessed = [re.sub(r'\s{2,}','',t) for t in preprocessed if t !='']
preprocessed = [t.strip() for t in preprocessed]
preprocessed
# Out:
# ['',
#  'I',
#  'Liang Hui Wang I',
#  '1·1',
#  'Mencius went to see king Hui of Liang',
#  'The king said Venerable sir since you have not counted it far to come here a distance of a thousand li may I presume that you are provided with counsels to profit my kingdom',
#  'Mencius replied Why must your Majesty use that word profit',
#  'What I am provided with are counsels to benevolence and righteousness and these are my only topics',
#  'If your Majesty say What is to be done to profit my kingdom',
#  'the great officers will say What is to be done to profit our families',
#  'and the inferior officers and the common people will say What is to be done to profit our persons',
#  'Superiors and inferiors will try to snatch this profit the one from the other and the kingdom will be endangered',
# ...

# %%
roman = [re.match(r'(V|I|X)?I{,5}X?V?',t) for t in preprocessed]
roman = sorted(list(set([t for t in [t.group() for t in roman] if t!='']))) #I, II, III, IV, V, ...
num_dot = [re.match(r'[0-9]+·[0-9]+',t) for t in preprocessed]
num_dot = sorted(list(set([t.group() for t in num_dot if t!=None]))) # 1·1, 1·2 , ...
subtitle = [re.match(r'^[A-Z][A-Za-z]+\s[A-Z][A-Za-z\s]+I{1,2}$',t) for t in preprocessed]
subtitle = sorted([t.group() for t in subtitle if t!=None]) #'Liang Hui Wang I','Liang Hui Wang II',...

# %%
subtitle
# Out:
# ['Gao Zi I',
#  'Gao Zi II',
#  'Gong Sun Chou I',
#  'Gong Sun Chou II',
#  'Jin Xin I',
#  'Jin Xin II',
#  'Li Lou I',
#  'Li Lou II',
#  'Liang Hui Wang I',
#  'Liang Hui Wang II',
#  'Teng Wen Gong I',
#  'Teng Wen Gong II',
#  'Wan Zhang I',
#  'Wan Zhang II']

# %%
num_dot[:9]
# Out:
# ['10·1', '10·3', '10·4', '10·5', '10·6', '10·7', '10·9', '11·9', '12·14']

# %%
{'roman':{'subtitle':{'num_dot':'텍스트','num_dot':'텍스트','num_dot':'텍스트'}}}
# Out:
# {'roman': {'subtitle': {'num_dot': '텍스트'}}}

# %%
#파일에 적힌 순서대로 각 값들을 나열하기
n_rom = [t for t in preprocessed if t in roman] 
n_sub = [t for t in preprocessed if t in subtitle]
n_num = [t for t in preprocessed if t in num_dot]

# %%
n_num #170개 챕터
# Out:
# ['1·1',
#  '1·2',
#  '1·4',
#  '1·5',
#  '1·6',
#  '1·7',
#  '2·1',
#  '2·2',
#  '2·4',
#  '2·5',
#  '2·6',
#  '2·7',
#  '2·8',
#  '2·10',
#  '2·11',
#  '2·12',
#  '2·16',
#  '3·1',
#  '3·2',
#  '3·3',
#  '3·9',
#  '4·2',
#  '4·5',
#  '4·6',
#  '4·11',
#  '4·12',
#  '4·13',
#  '5·3',
#  '6·4',
#  '6·5',
#  '6·6',
#  '6·7',
#  '6·8',
#  '6·10',
#  '7·1',
#  '7·2',
#  '7·3',
#  '7·5',
#  '7·6',
#  '7·7',
#  '7·8',
#  '7·9',
#  '7·13',
#  '7·14',
#  '7·16',
#  '7·20',
#  '8·3',
#  '8·4',
#  '8·5',
#  '8·9',
#  '8·17',
#  '8·22',
#  '8·24',
#  '8·32',
#  '8·33',
#  '9·2',
#  '9·3',
#  '9·5',
#  '9·6',
#  '10·1',
#  '10·3',
#  '10·4',
#  '10·5',
#  '10·6',
#  '10·7',
#  '10·9',
#  '11·9',
#  '12·4',
#  '12·8',
#  '12·9',
#  '12·14',
#  '13·8',
#  '13·17',
#  '13·31',
#  '13·35',
#  '13·43',
#  '14·1',
#  '14·4',
#  '14·7',
#  '14·8',
#  '14·11',
#  '14·12',
#  '14·13',
#  '14·14',
#  '14·20',
#  '14·27',
#  '14·28',
#  '14·30',
#  '14·34']

# %%
n_num_index = [] #챕터들의 '인덱스'를 담은 리스트 만들기
for p in preprocessed:
    if p in n_num:
        n_num_index.append(preprocessed.index(p))

# %%
len(n_num_index) #챕터들의 인덱스를 담은 리스트의 길이
# Out:
# 89

# %%
preprocessed.index('1·1') #리스트에서 값에 대한 인덱스 반환
# Out:
# 3

# %%
' '.join(preprocessed[3+1:27]) #' '.join(preprocessed[3:27])
# Out:
# 'Mencius went to see king Hui of Liang The king said Venerable sir since you have not counted it far to come here a distance of a thousand li may I presume that you are provided with counsels to profit my kingdom Mencius replied Why must your Majesty use that word profit What I am provided with are counsels to benevolence and righteousness and these are my only topics If your Majesty say What is to be done to profit my kingdom the great officers will say What is to be done to profit our families and the inferior officers and the common people will say What is to be done to profit our persons Superiors and inferiors will try to snatch this profit the one from the other and the kingdom will be endangered In the kingdom of ten thousand chariots the murderer of his sovereign shall be the chief of a family of a thousand chariots In the kingdom of a thousand chariots the murderer of his prince shall be the chief of a family of a hundred chariots To have a thousand in ten thousand and a hun
# ...

# %%
#각 챕터에 대응되는 본문 내용을 리스트로 담음(챕터 개수와 마찬가지로 총 89개)
content = []
for idx in range(len(n_num_index)):
    if idx < len(n_num_index)-1:
        tex=' '.join(preprocessed[n_num_index[idx]+1:n_num_index[idx+1]])
        content.append(tex)
    else:
        tex=' '.join(preprocessed[n_num_index[idx]+1:])
        content.append(tex)

# %%
len(content)
# Out:
# 89

# %%
content[88]
# Out:
# 'Mencius said Those who give counsel to the great should despise them and not look at their pomp and display Halls several times eight cubits high with beams projecting several cubits these if my wishes were to be realized I would not have Food spread before me over ten cubits square and attendants and concubines to the amount of hundreds these though my wishes were realized I would not have Pleasure and wine and the dash of hunting with thousands of chariots following after me these though my wishes were realized I would not have What they esteem are what I would have nothing to do with what I esteem are the rules of the ancients Why should I stand in awe of them'

# %%
dic_num_content={n:c for n, c in zip(n_num, content)} # {챕터명:내용} 형식의 딕셔너리 생성

# %%
dic_num_content['14·34']
# Out:
# 'Mencius said Those who give counsel to the great should despise them and not look at their pomp and display Halls several times eight cubits high with beams projecting several cubits these if my wishes were to be realized I would not have Food spread before me over ten cubits square and attendants and concubines to the amount of hundreds these though my wishes were realized I would not have Pleasure and wine and the dash of hunting with thousands of chariots following after me these though my wishes were realized I would not have What they esteem are what I would have nothing to do with what I esteem are the rules of the ancients Why should I stand in awe of them'

# %%
dic_num_content.keys()
# Out:
# dict_keys(['1·1', '1·2', '1·4', '1·5', '1·6', '1·7', '2·1', '2·2', '2·4', '2·5', '2·6', '2·7', '2·8', '2·10', '2·11', '2·12', '2·16', '3·1', '3·2', '3·3', '3·9', '4·2', '4·5', '4·6', '4·11', '4·12', '4·13', '5·3', '6·4', '6·5', '6·6', '6·7', '6·8', '6·10', '7·1', '7·2', '7·3', '7·5', '7·6', '7·7', '7·8', '7·9', '7·13', '7·14', '7·16', '7·20', '8·3', '8·4', '8·5', '8·9', '8·17', '8·22', '8·24', '8·32', '8·33', '9·2', '9·3', '9·5', '9·6', '10·1', '10·3', '10·4', '10·5', '10·6', '10·7', '10·9', '11·9', '12·4', '12·8', '12·9', '12·14', '13·8', '13·17', '13·31', '13·35', '13·43', '14·1', '14·4', '14·7', '14·8', '14·11', '14·12', '14·13', '14·14', '14·20', '14·27', '14·28', '14·30', '14·34'])

# %%
#소제목('Liang Hui Wang II' 등)별로 '챕터'를 묶은 리스트를 담은 하나의 리스트 생성(이중 리스트)
ls = []
for i in range(1,15): 
    ls2 = []
    for n in n_num:
        if n.startswith(str(i)+'·'):
            ls2.append(n)
    ls.append(ls2)

# %%
ls[:3]
# Out:
# [['1·1', '1·2', '1·4', '1·5', '1·6', '1·7'],
#  ['2·1',
#   '2·2',
#   '2·4',
#   '2·5',
#   '2·6',
#   '2·7',
#   '2·8',
#   '2·10',
#   '2·11',
#   '2·12',
#   '2·16'],
#  ['3·1', '3·2', '3·3', '3·9']]

# %%
#소제목('Liang Hui Wang II' 등)별로 '본문 내용'을 묶은 리스트를 담은 하나의 리스트 생성(이중 리스트)
sl = []
for c in ls:
    sl2 = []
    for k in c:
        sl2.append(dic_num_content[k])
    sl.append(sl2)

# %%
sl[1]
# Out:
# ['Zhuang Bao seeing Mencius said to him I had an interview with the king His Majesty told me that he loved music and I was not prepared with anything to reply to him What do you pronounce about that love of music Mencius replied If the kings love of music were very great the kingdom of Qi would be near to a state of good government Another day Mencius having an interview with the king said Your Majesty I have heard told the officer Zhuang that you love music · was it so The king changed colour and said I am unable to love the music of the ancient sovereigns I only love the music that suits the manners of the present age Mencius said If your Majestys love of music were very great Qi would be near to a state of good government The music of the present day is just like the music of antiquity as regards effecting that The king said May I hear from you the proof of that Mencius asked Which is the more pleasant · to enjoy music by yourself alone or to enjoy it with others To enjoy it with 
# ...

# %%
#소제목별로 각 챕터를 key, 챕터에 대응되는 내용을 value로 하는 딕셔너리를 만들고 각 딕셔너리를 담은 하나의 리스트를 생성
new_ls=[]
for k, v in zip(ls, sl): #[['1·3'], ['2·3', '2·9', '2·13', '2·14', '2·15'], ...] , [[내용], [내용,내용,내용,내용,내용], ...]
    dic={}
    for x, y in zip(k,v):
        dic[x]=y
    new_ls.append(dic)

# %%
len(new_ls)
# Out:
# 14

# %%
new_ls[0] # [{'1·3':내용}, {'2·3':내용,'2·9':내용,'2·13':내용,'2·14':내용,'2·15':내용}, {...}, ...]
# Out:
# {'1·1': 'Mencius went to see king Hui of Liang The king said Venerable sir since you have not counted it far to come here a distance of a thousand li may I presume that you are provided with counsels to profit my kingdom Mencius replied Why must your Majesty use that word profit What I am provided with are counsels to benevolence and righteousness and these are my only topics If your Majesty say What is to be done to profit my kingdom the great officers will say What is to be done to profit our families and the inferior officers and the common people will say What is to be done to profit our persons Superiors and inferiors will try to snatch this profit the one from the other and the kingdom will be endangered In the kingdom of ten thousand chariots the murderer of his sovereign shall be the chief of a family of a thousand chariots In the kingdom of a thousand chariots the murderer of his prince shall be the chief of a family of a hundred chariots To have a thousand in ten thousand a
# ...

# %%
type(new_ls)
# Out:
# list

# %%
#소제목을 key로, 위에서 만든 딕셔너리를 value로 하는 딕셔너리를 만들고 그 딕셔너리들을 담은 하나의 리스트를 생성
#여기서 만들어진 리스트는 뒤에서 제목(로마자 숫자(I, II, III, IV, V, ...))에 대응됨
new_ls2=[{k:v} for k, v in zip(n_sub, new_ls)]

# %%
len(new_ls2)
# Out:
# 14

# %%
#제목을 key로, 위에서 만든 딕셔너리를 value로 하는 하나의 딕셔너리를 생성(최종 데이터 구조)
mencius_data_structure={k:v for k, v in zip(n_rom, new_ls2)}

# %%
mencius_data_structure['II']['Liang Hui Wang II']['2·1'] #내용 탐색 방법1
# Out:
# 'Zhuang Bao seeing Mencius said to him I had an interview with the king His Majesty told me that he loved music and I was not prepared with anything to reply to him What do you pronounce about that love of music Mencius replied If the kings love of music were very great the kingdom of Qi would be near to a state of good government Another day Mencius having an interview with the king said Your Majesty I have heard told the officer Zhuang that you love music · was it so The king changed colour and said I am unable to love the music of the ancient sovereigns I only love the music that suits the manners of the present age Mencius said If your Majestys love of music were very great Qi would be near to a state of good government The music of the present day is just like the music of antiquity as regards effecting that The king said May I hear from you the proof of that Mencius asked Which is the more pleasant · to enjoy music by yourself alone or to enjoy it with others To enjoy it with o
# ...

# %%
mencius_data_structure['II']['Liang Hui Wang II'].values() #내용 탐색 방법1
# Out:
# dict_values(['Zhuang Bao seeing Mencius said to him I had an interview with the king His Majesty told me that he loved music and I was not prepared with anything to reply to him What do you pronounce about that love of music Mencius replied If the kings love of music were very great the kingdom of Qi would be near to a state of good government Another day Mencius having an interview with the king said Your Majesty I have heard told the officer Zhuang that you love music · was it so The king changed colour and said I am unable to love the music of the ancient sovereigns I only love the music that suits the manners of the present age Mencius said If your Majestys love of music were very great Qi would be near to a state of good government The music of the present day is just like the music of antiquity as regards effecting that The king said May I hear from you the proof of that Mencius asked Which is the more pleasant · to enjoy music by yourself alone or to enjoy it with others To en
# ...

# %%
len(mencius_data_structure['II']['Liang Hui Wang II'].values())
# Out:
# 11

# %%
# 딕셔너리구조로 변환된 맹자절문 삭제부분 데이터 저장하기
with open(r"C:\Users\admin\Desktop\Mencius_research\Mencius_research\deleted_dict_structure.pickle",'wb') as f:
    pickle.dump(mencius_data_structure, f)

# %%
# 딕셔너리구조로 변환된 맹자절문 삭제부분 데이터 불러오기
with open(r"C:\Users\admin\Desktop\Mencius_research\Mencius_research\deleted_dict_structure.pickle",'rb') as f:
    mencius_deleted = pickle.load(f)

# %%
#잘 불러왔는지 확인
mencius_deleted['II']['Liang Hui Wang II']['2·1']
# Out:
# 'Zhuang Bao seeing Mencius said to him I had an interview with the king His Majesty told me that he loved music and I was not prepared with anything to reply to him What do you pronounce about that love of music Mencius replied If the kings love of music were very great the kingdom of Qi would be near to a state of good government Another day Mencius having an interview with the king said Your Majesty I have heard told the officer Zhuang that you love music · was it so The king changed colour and said I am unable to love the music of the ancient sovereigns I only love the music that suits the manners of the present age Mencius said If your Majestys love of music were very great Qi would be near to a state of good government The music of the present day is just like the music of antiquity as regards effecting that The king said May I hear from you the proof of that Mencius asked Which is the more pleasant · to enjoy music by yourself alone or to enjoy it with others To enjoy it with o
# ...
